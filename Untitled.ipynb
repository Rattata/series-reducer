# %%
using DataFrames; using GLM; using Gadfly;
# Out:
# INFO: Precompiling module Gadfly.

# %%
table = readcsv("D:\\lab\\series-reducer\\6df85afc-36cb-46c9-98dd-dd6f70322d551117945382446426219.csv"; skipstart=1)
# Out:
# 600×13 Array{Float64,2}:
#  128.0        2369.0             4.0731e6   …       1.93865e6       1.0544e6
#  128.0        2368.0        275145.0           893729.0        978996.0
#  128.0        3158.0        284619.0           765038.0        843989.0
#  128.0        2368.0        268829.0           821488.0        958863.0
#  128.0        2369.0        264486.0           755959.0        967153.0
#  128.0        2368.0        273961.0        …       1.50126e6  851885.0
#  128.0        2369.0        279883.0           883859.0        912677.0
#  128.0        3553.0        254223.0           840436.0        778460.0
#  128.0        2369.0        216721.0           828199.0        808066.0
#  128.0        2368.0        221853.0           733852.0        827409.0
#  128.0        3948.0        223432.0        …  794250.0             1.01768e6
#  128.0        2368.0        238433.0           753195.0        846358.0
#  128.0        3947.0        225800.0           804118.0        877544.0
# ...

# %%
values = Array{Float64}((600*12),3)
for r in 1:600
    for c in 2:13
        a = [table[r,1],Float64(c - 1),table[r,c]]
        values[(r - 1) * 12 + (c - 1), :]  = a
    end
end
values = DataFrame(values)
rename!(values, :x3, :time_ns); rename!(values, :x2, :threads); rename!(values, :x1, :N);
# Out:
# 7200×3 DataFrames.DataFrame
# │ Row  │ x1        │ x2   │ x3        │
# ├──────┼───────────┼──────┼───────────┤
# │ 1    │ 128.0     │ 1.0  │ 2369.0    │
# │ 2    │ 128.0     │ 2.0  │ 4.0731e6  │
# │ 3    │ 128.0     │ 3.0  │ 385282.0  │
# │ 4    │ 128.0     │ 4.0  │ 406204.0  │
# │ 5    │ 128.0     │ 5.0  │ 438574.0  │
# │ 6    │ 128.0     │ 6.0  │ 531737.0  │
# │ 7    │ 128.0     │ 7.0  │ 555422.0  │
# │ 8    │ 128.0     │ 8.0  │ 637137.0  │
# │ 9    │ 128.0     │ 9.0  │ 708982.0  │
# │ 10   │ 128.0     │ 10.0 │ 758327.0  │
# │ 11   │ 128.0     │ 11.0 │ 1.93865e6 │
# ⋮
# │ 7189 │ 6.71089e7 │ 1.0  │ 2.69942e7 │
# │ 7190 │ 6.71089e7 │ 2.0  │ 2.33301e7 │
# │ 7191 │ 6.71089e7 │ 3.0  │ 1.72161e7 │
# │ 7192 │ 6.71089e7 │ 4.0  │ 1.40375e7 │
# │ 7193 │ 6.71089e7 │ 5.0  │ 1.86246e7 │
# │ 7194 │ 6.71089e7 │ 6.0  │ 1.60066e7 │
# │ 7195 │ 6.71089e7 │ 7.0  │ 1.45614e7 │
# │ 7196 │ 6.71089e7 │ 8.0  │ 1.37731e7 │
# │ 7197 │ 6.71089e7 │ 9.0  │ 1.7149e7  │
# │ 7198 │ 6.71089e7 │ 10.0 │ 1.55877e7 │
# ...

# %% [markdown]
# ### Linear regression
# As you can see below, increases in N confirm the algorithm has a time complexity of O(n)

# %%
model = glm(@formula(time_ns ~ threads + N), values, Normal(), IdentityLink())
# Out:
# DataFrames.DataFrameRegressionModel{GLM.GeneralizedLinearModel{GLM.GlmResp{Array{Float64,1},Distributions.Normal{Float64},GLM.IdentityLink},GLM.DensePredChol{Float64,Base.LinAlg.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# Formula: x3 ~ 1 + x2 + x1
#
# Coefficients:
#               Estimate   Std.Error  z value Pr(>|z|)
# (Intercept)  7.30281e5     33641.8  21.7076   <1e-99
# x2            -49879.1     4484.79 -11.1218   <1e-28
# x1            0.288222 0.000969115  297.408   <1e-99

# %%
valuesmedian = Array{Float64,2}(0,3);
for i in unique(values[:,:N])
    for j in unique(values[:,:threads])
        subset = values[(values[:N].==i).&(values[:threads].==j),:]
        valuesmedian = vcat(valuesmedian,[i , j, mean(subset[:time_ns])]')
    end
end
valuesmedian = DataFrame(valuesmedian);
rename!(valuesmedian, :x3, :median_time_ns); rename!(valuesmedian, :x2, :threads); rename!(valuesmedian, :x1, :N);
valuesmedian
# Out:
# 240×3 DataFrames.DataFrame
# │ Row │ N         │ threads │ median_time_ns │
# ├─────┼───────────┼─────────┼────────────────┤
# │ 1   │ 128.0     │ 1.0     │ 2631.8         │
# │ 2   │ 128.0     │ 2.0     │ 3.64044e5      │
# │ 3   │ 128.0     │ 3.0     │ 2.57737e5      │
# │ 4   │ 128.0     │ 4.0     │ 3.02831e5      │
# │ 5   │ 128.0     │ 5.0     │ 3.76532e5      │
# │ 6   │ 128.0     │ 6.0     │ 4.20244e5      │
# │ 7   │ 128.0     │ 7.0     │ 4.94511e5      │
# │ 8   │ 128.0     │ 8.0     │ 561620.0       │
# │ 9   │ 128.0     │ 9.0     │ 6.12701e5      │
# │ 10  │ 128.0     │ 10.0    │ 6.65915e5      │
# │ 11  │ 128.0     │ 11.0    │ 8.21383e5      │
# ⋮
# │ 229 │ 6.71089e7 │ 1.0     │ 3.03459e7      │
# │ 230 │ 6.71089e7 │ 2.0     │ 2.73735e7      │
# │ 231 │ 6.71089e7 │ 3.0     │ 2.17434e7      │
# │ 232 │ 6.71089e7 │ 4.0     │ 1.97278e7      │
# │ 233 │ 6.71089e7 │ 5.0     │ 1.86875e7      │
# │ 234 │ 6.71089e7 │ 6.0     │ 1.68782e7      │
# ...

# %%
valuesmedian[:load_p_mns] = map((x,y) -> y / x, valuesmedian[:median_time_ns], valuesmedian[:N] );
p = plot(valuesmedian[(valuesmedian[:threads].<=8),:], x="threads", y ="load_p_mns", color="N", Geom.point, Geom.line)
# Out:
# Plot(...)

# %%
opt = DataFrame(Array{Float64,2}(0,0));
for i in unique(valuesmedian[:,:N])
    subset = valuesmedian[(valuesmedian[:N].==i),:]
    sort!(subset, cols = order(:load_p_mns), rev = true)
    opt = vcat(opt,subset[1,:])
end
println(opt)
plot(opt[(opt[:N].>= (2 ^17)),:], x="N", y ="median_time_ns", color="threads", Geom.point, Geom.line)
# Out:
# 20×4 DataFrames.DataFrame
# │ Row │ N         │ threads │ median_time_ns │ load_p_mns │
# ├─────┼───────────┼─────────┼────────────────┼────────────┤
# │ 1   │ 128.0     │ 1.0     │ 2631.8         │ 0.0486359  │
# │ 2   │ 256.0     │ 1.0     │ 5237.1         │ 0.048882   │
# │ 3   │ 512.0     │ 1.0     │ 9724.1         │ 0.0526527  │
# │ 4   │ 1024.0    │ 1.0     │ 8421.4         │ 0.121595   │
# │ 5   │ 2048.0    │ 1.0     │ 4526.6         │ 0.452437   │
# │ 6   │ 4096.0    │ 1.0     │ 1723.63        │ 2.37638    │
# │ 7   │ 8192.0    │ 1.0     │ 3434.53        │ 2.38519    │
# │ 8   │ 16384.0   │ 1.0     │ 6618.8         │ 2.47537    │
# │ 9   │ 32768.0   │ 1.0     │ 12316.4        │ 2.66052    │
# │ 10  │ 65536.0   │ 1.0     │ 25053.8        │ 2.61581    │
# │ 11  │ 131072.0  │ 1.0     │ 56265.9        │ 2.32951    │
# │ 12  │ 262144.0  │ 1.0     │ 1.14045e5      │ 2.2986     │
# │ 13  │ 524288.0  │ 1.0     │ 2.24814e5      │ 2.3321     │
# ...
